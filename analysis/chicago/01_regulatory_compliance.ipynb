# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

from langchain_core.tools import tool
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# Load helper functions and setup
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(project_root)

from analysis.chicago.setup import setup_llm_and_graph
from analysis.chicago.utils import run_validation_pipeline, parse_shacl_result, process_agent_step
from analysis.chicago.regulatory_compliance.prompt import SHACL_PROMPTS, AGENT_PROMPTS
from analysis.chicago.regulatory_compliance.regulatory_utils import run_explainability_query

llm, neo4j_graph = setup_llm_and_graph()

# %% [markdown]
# # SHACL Validation Test

# %%
# Test the generation of the SHACL rules
rdf_schema = SHACL_PROMPTS["rdf_schema"]
message = SHACL_PROMPTS["message"]

prompt = PromptTemplate(
    input_variables=["message", "rdf_schema"],
    template=SHACL_PROMPTS["template"]
)

chain = prompt | llm | StrOutputParser()
sparql_query = chain.invoke({"message": message, "rdf_schema": rdf_schema})
shacl_shape = f'''
@prefix sh: <http://www.w3.org/ns/shacl#> .
@prefix gr: <http://purl.org/goodrelations/v1#> .
@prefix pco: <http://purl.org/procurement/public-contracts#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .

<#BusinessLicenseContractShape> a sh:NodeShape ;
    sh:targetClass gr:BusinessEntity ;
    sh:message "The newest license end date must not be before the oldest contract start date." ;
    sh:sparql [
        a sh:SPARQLConstraint ;
        sh:message "The newest license end date must not be before the oldest contract start date." ;
        sh:select \"\"\" {sparql_query}\"\"\" ;
    ] .
'''
print(shacl_shape)
# Out:
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix gr: <http://purl.org/goodrelations/v1#> .
# @prefix pco: <http://purl.org/procurement/public-contracts#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <#BusinessLicenseContractShape> a sh:NodeShape ;
#     sh:targetClass gr:BusinessEntity ;
#     sh:message "The newest license end date must not be before the oldest contract start date." ;
#     sh:sparql [
#         a sh:SPARQLConstraint ;
#         sh:message "The newest license end date must not be before the oldest contract start date." ;
#         sh:select """ SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }""" ;
#     ] .

# %%
conforms, results_graph, results_text = run_validation_pipeline("../../data/chicago/compliance.ttl", shacl_shape)
# Out:
# Data Graph has 1117563 statements.
# SHACL Graph has 7 statements.

# %%
print(results_text)
# Out:
# Validation Report
# Conforms: False
# Results (13):
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?maxLicenseEndDate ?minContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?maxLicenseEndDate) WHERE {
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?minContractStartDate) WHERE {
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxLicenseEndDate < ?minContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.

# %% [markdown]
# # LangGraph React Agent

# %%
import json

@tool
def generate_shacl_shape(rdf_schema: str, message: str):
    """
    Generates a SHACL NodeShape based on the RDF schema and a message describing the validation.

    Expects two parameters:
      - 'rdf_schema': a string with RDF prefixes and assumptions
      - 'message': a string describing the SHACL rule to implement
    Returns the SHACL NodeShape in Turtle syntax as a string.
    """

    if not rdf_schema or not message:
        return "Error: 'rdf_schema' and 'message' must be provided."

    prompt = SHACL_PROMPTS["template"]

    return prompt

@tool
def run_shacl_validation(unused: str):
    """Process and report SHACL validation results from a structured representation of Graph data"""
    graph_data = parse_shacl_result(results_graph)
    graph_data_str = json.dumps(graph_data, indent=2)
    return graph_data_str

@tool
def get_context_from_neo4j(nodes_with_issues: list):
    """
    For each node, fetch actual related context from Neo4j using the configured Cypher queries.
    Returns real query results.
    """

    return run_explainability_query(neo4j_graph, nodes_with_issues)


tools = [generate_shacl_shape, run_shacl_validation, get_context_from_neo4j]

# %%
from langgraph.prebuilt import create_react_agent

def explain_shacl_issues(llm, tools):
    """
    Run a LangGraph agent to summarize and explain SHACL validation results,
    including deeper insights via Cypher queries.
    
    Parameters:
        llm: The language model instance.
        tools: List of tools including any CypherQuery tool needed.
    
    Returns:
        The explanation string from the agent's final message.
    """

    # System message (persona and scope)
    system_message = (
        "You are helpful assistant that it is able to generate SPARQL query for RDF validation."
        "You are a helpful assistant who reports SHACL validation issues and explains them clearly. "
        "You have access to context through Cypher queries and can analyze ContractRecord and LicenseRecord details."
    )

    # Build the LangGraph REAct-style agent
    langgraph_agent_executor = create_react_agent(llm, tools, prompt=system_message)

    # Structured, improved prompt
    base_query = AGENT_PROMPTS["explain"]

    # Invoke the agent
    print("---DEBUGGING")
    for step in langgraph_agent_executor.stream({"messages": [("human", base_query)]}):
        process_agent_step(step)
    
    print("---FINAL VERSION")
    response = langgraph_agent_executor.invoke({"messages": [("human", base_query)]})
    return response["messages"][-1].content

# %%
response = explain_shacl_issues(llm=llm, tools=tools)
print(response)
# Out:
# ---DEBUGGING
#
# === Agent Step ===
#
# 🔧 Tool Call: generate_shacl_shape
# 🧾 Arguments:
#   - rdf_schema: @prefix ex: <http://example.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:ContractR...
#   - message: Validate that for each ContractRecord, the startDate is before the endDate, and for each LicenseReco...
#
# === Tool Results ===
#
# 🛠️ Tool Name: generate_shacl_shape
# 🆔 Tool Call ID: call_cocnkzZnZqabbmN48S3faT2i
# 📄 Content:
# You are an expert in SHACL and SPARQL.
#
#         Given the following RDF schema (Turtle format):
#         {rdf_schema}
#
#         And the given message:
#         "{message}"
#
#         Write only the SPARQL SELECT query that enforces this rule.
#         Do not include any explanations, comments, SHACL syntax, sparql or RDF prefixes.
#         Do not include any sparql quote.
#         Output only the raw SPARQL query, starting directly with SELECT.
#
#
# === Agent Step ===
#
# 🔧 Tool Call: run_shacl_validation
# 🧾 Arguments:
#   - unused:
#
# === Tool Results ===
#
# 🛠️ Tool Name: run_shacl_validation
# 🆔 Tool Call ID: call_pAB27ENprbdlyM4D298BsCO5
# 📄 Content:
# [
#   {
#     "common": {
#       "message": "The newest license end date must not be before the oldest contract start date.",
#       "path": null,
#       "severity": "Violation",
#       "source_shape": "file:///Users/giuseppefutia/Desktop/code/klab/analysis/chicago/#BusinessLicenseContractShape"
#     },
#     "focus_nodes": [
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893",
#       "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998"
#     ]
#   }
# ]
#
# === Agent Step ===
#
# 🔧 Tool Call: get_context_from_neo4j
# 🧾 Arguments:
#   - nodes_with_issues: ['http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998']
#
# === Tool Results ===
#
# 🛠️ Tool Name: get_context_from_neo4j
# 🆔 Tool Call ID: call_9EIqp8e4WYSpF0ybl0vn9dga
# 📄 Content:
# [{"node": "4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214", "results": [{"mapping": "HAS_VENDOR", "query": "MATCH path=(c:Contract)<-[:INCLUDED_IN_CONTRACT]-(contractRecord:ContractRecord)-[:HAS_VENDOR]->(contractOrg:Organization)-[:BELONGS_TO_ORG_GROUP]->(o:OrganizationGroup)\n                        WHERE elementId(o) = $node_id\n                        RETURN DISTINCT contractRecord, contractOrg", "data": [{"contractRecord": {"specificationId": "113982", "amount": 1000.0, "approvalDate": "12/18/2012", "pdfFile": "http://ecm.cityofchicago.org/eSMARTContracts/service/DPSWebDocumentViewer?sid=ESMART&id={7A1DB099-06F7-4D84-BA4A-E9B16CE46997}", "endDate": "12/31/2012", "name": "Second Half of NAP 2012", "contractId": "27513", "vendorId": "94581218A", "id": 124904, "source": "CONTRACTS", "startDate": "01/01/2012"}, "contractOrg": {"addresses": ["1217 W ROSEMONT AVE"], "componentId": 114855, "names": ["MARTHA SANDERS"], "addressCities": ["CHICAGO"], "name": "MARTHA SANDERS", "addressPostalCodes": ["60660"], "id": "94581218A", "source": "CONTRACTS", "addressStates": ["IL"]}}, {"contractRecord": {"specificationId": "131099", "amount": 1400.0, "approvalDate": "03/23/2015", "pdfFile": "http://ecm.cityofchicago.org/eSMARTContracts/service/DPSWebDocumentViewer?sid=ESMART&id={388FBF24-200A-4B77-A34D-12BB5DC0D085}", "endDate": "08/31/2015", "name": "Individual Artist Program (IAP) Professional Development Cycle1", "contractId": "32100", "vendorId": "94581218A", "id": 125438, "source": "CONTRACTS", "startDate": "01/01/2015"}, "contractOrg": {"addresses": ["1217 W ROSEMONT AVE"], "componentId": 114855, "names": ["MARTHA SANDERS"], "addressCities": ["CHICAGO"], "name": "MARTHA SANDERS", "addressPostalCodes": ["60660"], "id": "94581218A", "source": "CONTRACTS", "addressStates": ["IL"]}}, {"contractRecord": {"specificationId": "1185597", "amount": 4500.0, "approvalDate": "07/26/2019", "pdfFile": "http://ecm.cityofchicago.org/eSMARTContracts/service/DPSWebDocumentViewer?sid=ESMART&id={E0484E73-0000-C71A-8B55-18E637DED738}", "endDate": "12/31/2019", "name": "Grant Agreement, IAP, Sanders", "contractId": "107360", "vendorId": "94581218A", "id": 125921, "source": "CONTRACTS", "startDate": "01/01/2019"}, "contractOrg": {"addresses": ["1217 W ROSEMONT AVE"], "componentId": 114855, "names": ["MARTHA SANDERS"], "addressCities": ["CHICAGO"], "name": "MARTHA SANDERS", "addressPostalCodes": ["60660"], "id": "94581218A", "source": "CONTRACTS", "addressStates": ["IL"]}}, {"contractRecord": {"specificationId": "243007", "amount": 4100.0, "approvalDate": "07/07/2016", "pdfFile": "http://ecm.cityofchicago.org/eSMARTContracts/service/DPSWebDocumentViewer?sid=ESMART&id={D3472DA8-4102-4839-8E11-C323195F72CF}", "endDate": "08/31/2016", "name": "Individual Artist Program (IAP) Creative Projects", "contractId": "42556", "vendorId": "94581218A", "id": 139871, "source": "CONTRACTS", "startDate": "01/01/2016"}, "contractOrg": {"addresses": ["1217 W ROSEMONT AVE"], "componentId": 114855, "names": ["MARTHA SANDERS"], "addressCities": ["CHICAGO"], "name": "MARTHA SANDERS", "addressPostalCodes": ["60660"], "id": "94581218A", "source": "CONTRACTS", "addressStates": ["IL"]}}, {"contractRecord": {"specificationId": "119171", "amount": 4000.0, "approvalDate": "08/06/2013", "pdfFile": "http://ecm.cityofchicago.org/eSMARTContracts/service/DPSWebDocumentViewer?sid=ESMART&id={2BB3111C-42AB-4D24-B883-BFD31E33C277}", "endDate": "12/01/2013", "name": "2013 Individual Artists Program", "contractId": "28547", "vendorId": "94581218A", "id": 144388, "source": "CONTRACTS", "startDate": "01/01/2013"}, "contractOrg": {"addresses": ["1217 W ROSEMONT AVE"], "componentId": 114855, "names": ["MARTHA SANDERS"], "addressCities": ["CHICAGO"], "name": "MARTHA SANDERS", "addressPostalCodes": ["60660"], "id": "94581218A", "source": "CONTRACTS", "addressStates": ["IL"]}}, {"contractRecord": {"specificationId": "520633", "amount": 4500.0, "approvalDate": "08/14/2017", "pdfFile": "http://ecm.cityofchic ...
#
# === Agent Step ===
# ---FINAL VERSION
# Summary of SHACL Validation Issues:
# - The validation rule checks that for each ContractRecord and LicenseRecord, the startDate must be before the endDate.
# - The validation found violations where the newest license end date is before the oldest contract start date for several business entities.
#
# How to Fix Each Issue:
# - Ensure that for each ContractRecord and LicenseRecord, the startDate is strictly before the endDate.
# - Review and correct the date fields in the contract and license records to maintain chronological order.
#
# Affected Nodes (Business Entities):
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893
# - 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998
#
# Details for Selected Nodes (Prioritizing ContractRecord and LicenseRecord with contractOrg and licenseOrg):
#
# 1. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214
#    - ContractRecords (vendor: MARTHA SANDERS) have startDates from 01/01/2012 to 01/01/2020 and endDates from 12/31/2012 to 12/31/2021.
#    - LicenseRecords (licenseOrg: MARTHA E SANDERS) have endDates as early as 08/15/2003 and startDates from 08/16/2002.
#    - Issue: License end dates are before some contract start dates, violating the chronological order.
#
# 2. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112
#    - ContractRecords (vendor: DOCK'S) have startDates around 06/27/2003 to 06/29/2007 and endDates from 07/06/2003 to 07/08/2007.
#    - LicenseRecords (licenseOrg: DOCK'S GREAT FISH, INC) have endDates around 05/15/2003 and startDates from 05/16/2002.
#    - Issue: Some contract endDates are before license startDates or license endDates are before contract startDates.
#
# 3. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645
#    - ContractRecord (vendor: MICHELLE MCFARLAND-MCDANIELS) has startDate 01/01/2012 and endDate 12/31/2012.
#    - LicenseRecords (licenseOrg: MICHELLE N MCFARLAND) have endDates as early as 11/15/2003 and startDates from 11/16/2002.
#    - Issue: License endDates are before contract startDates.
#
# 4. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773
#    - ContractRecords (vendor: VANDERCOOK COLLEGE OF MUSIC) have startDates from 01/01/2020 to 01/01/2022 and endDates from 12/31/2021 to 12/31/2023.
#    - LicenseRecords (licenseOrg: VANDERCOOK COLLEGE OF MUSIC) have endDates as early as 08/15/2003 and startDates from 08/16/2003.
#    - Issue: License endDates are before some contract startDates.
#
# 5. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803
#    - ContractRecords (vendor: BLAIR THOMAS & COMPANY) have startDates from 01/01/2022 and endDates up to 12/31/2023.
#    - LicenseRecords (licenseOrg: BLAIR THOMAS AND COMPANY) have endDates as early as 08/15/2006 and startDates from 08/17/2005.
#    - Issue: License endDates are before contract startDates.
#
# 6. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236
#    - ContractRecord (vendor: STAGE LEFT THEATRE,INC) has startDate 07/01/2016 and endDate 12/31/2016.
#    - LicenseRecords (licenseOrg: Stage Left, Inc.) have endDates as early as 02/15/2003 and startDates from 02/16/2002.
#    - Issue: License endDates are before contract startDates.
#
# 7. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420
#    - ContractRecord (vendor: KARLA LOVE) has startDate 01/25/2011 and endDate 12/31/2015.
#    - LicenseRecords (licenseOrg: KARLA LOVE-DAVIS) have endDates as early as 12/15/2008 and startDates from 02/16/2007.
#    - Issue: License endDates are before contract startDates.
#
# 8. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344
#    - ContractRecords (vendor: COURT THEATRE FUND) have startDates from 01/01/2021 to 01/01/2022 and endDates from 12/31/2021 to 12/31/2023.
#    - LicenseRecords (licenseOrg: COURT THEATRE FUND) have endDates as early as 08/15/2003 and startDates from 04/14/2003.
#    - Issue: License endDates are before contract startDates.
#
# 9. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557
#    - ContractRecord (vendor: LEAH S COWEN) has startDate 01/01/2022 and endDate 12/31/2022.
#    - LicenseRecord (licenseOrg: LEAH SHOSHANAH COWEN) has endDate 06/15/2019 and startDate 06/12/2017.
#    - Issue: License endDate is before contract startDate.
#
# 10. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645
#     - ContractRecords (vendor: CHICAGO KIDS COMPANY) have startDates from 01/01/2017 to 01/01/2022 and endDates from 12/31/2017 to 12/31/2023.
#     - LicenseRecords (licenseOrg: CHICAGO KIDS COMPANY) have endDates as early as 08/15/2003 and startDates from 08/16/2002.
#     - Issue: License endDates are before contract startDates.
#
# 11. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361
#     - ContractRecord (vendor: JOYOUS YEARS YOUTH EMPOWERMENT PROGRAM (JYYEP)) has startDate 01/01/2013 and endDate 12/31/2013.
#     - LicenseRecords (licenseOrg: JOYOUS YEARS) have endDates as early as 10/15/2005 and startDates from 10/16/2008.
#     - Issue: License endDates are before contract startDates.
#
# 12. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893
#     - ContractRecords (vendor: WICKER PARK BUCKTOWN CHAMBER OF COMMERCE) have startDates from 01/01/2021 to 01/01/2023 and endDates up to 12/31/2023.
#     - LicenseRecords (licenseOrg: THE WICKER PARK & BUCKTOWN CHAMBER OF COMMERCE) have endDates as early as 07/26/2015 and startDates from 07/20/2015.
#     - Issue: License endDates are before contract startDates.
#
# 13. Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998
#     - ContractRecord (vendor: RICHARD HUNT) has startDate 12/01/2014 and endDate 04/15/2016.
#     - LicenseRecords (licenseOrg: RICHARD HUNT) have endDates as early as 05/15/2004 and startDates from 03/04/2004.
#     - Issue: License endDates are before contract startDates.
#
# Generated SPARQL Query for SHACL Validation:
#
# SELECT ?record ?startDate ?endDate WHERE {
#   {
#     ?record a <http://example.org/ContractRecord> ;
#             <http://example.org/startDate> ?startDate ;
#             <http://example.org/endDate> ?endDate .
#   }
#   UNION
#   {
#     ?record a <http://example.org/LicenseRecord> ;
#             <http://example.org/startDate> ?startDate ;
#             <http://example.org/endDate> ?endDate .
#   }
#   FILTER (?startDate >= ?endDate)
# }
#
# Summary:
# The validation errors are caused by license records having end dates that are earlier than the start dates of contract records for the same business entities. To fix these issues, the date fields in the contract and license records should be reviewed and corrected to ensure that the startDate is always before the endDate, and that license periods do not end before contract periods start. This will maintain proper chronological consistency between contracts and licenses.
