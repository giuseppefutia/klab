# %%
import sys
import os
import configparser

from pyshacl import validate
from rdflib import Graph, RDF, SH
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(project_root)

from database.neo4j_db import Neo4jGraphDB

# %%
# Load configuration
config = configparser.ConfigParser()
config.read('../../config.ini')

openai_api_key = config["openai"]["api_key"]
openai_model = config["openai"].get("model", "gpt-4.1-mini")

# Initialize OpenAI LLM
llm = ChatOpenAI(
    model=openai_model,
    api_key=openai_api_key,
    temperature=0,
    max_tokens=10000,
    timeout=3000
)

# GraphDatabase
neo4j_graph = Neo4jGraphDB()

# %% [markdown]
# # SHACL Validation

# %%
# Parse data
g = Graph()
g.parse("../../data/chicago/chicago.ttl", format="ttl")
print(f'Graph has {len(g)} statements.')
# Out:
# Graph has 1117563 statements.

# %%
# Generate SHACL rule with LLMs
rdf_schema = """
@prefix gr: <http://purl.org/goodrelations/v1#> .
@prefix pco: <http://purl.org/procurement/public-contracts#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .

# Assume: gr:BusinessEntity, gr:hasLicense, pco:actualEndDate, pco:bidder, pco:startDate
"""

message = """
- Find organizations (?this) where the end date of their latest license is earlier than the start date of their earliest contract.
- For each organization, get the maximum pco:actualEndDate from licenses linked by gr:hasLicense and the minimum pco:startDate from contracts linked by pco:bidder.
- Use subqueries to calculate these values, including ?this and the aggregated date (MAX or MIN) in both the SELECT and WHERE clauses of each subquery.
- Only return organizations where the newest license end date is before the oldest contract start date.
- Make sure to follow the correct relationship directions.
"""

prompt = PromptTemplate(
    input_variables=["message", "rdf_schema"],
    template="""
You are an expert in SHACL and SPARQL.

Given the following RDF schema (Turtle format):
{rdf_schema}

And the given message:
"{message}"

Write only the SPARQL SELECT query that enforces this rule. 
Do not include any explanations, comments, SHACL syntax, sparql or RDF prefixes.
Do not include any sparql quote. 
Output only the raw SPARQL query, starting directly with SELECT.
"""
)

chain = prompt | llm | StrOutputParser()
sparql_query = chain.invoke({"message": message, "rdf_schema": rdf_schema})
print(sparql_query)
# Out:
# SELECT ?this ?maxEndDate ?minStartDate WHERE {
#   {
#     SELECT ?this (MAX(?endDate) AS ?maxEndDate) WHERE {
#       ?this a <http://purl.org/goodrelations/v1#BusinessEntity> .
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?endDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?startDate) AS ?minStartDate) WHERE {
#       ?this a <http://purl.org/goodrelations/v1#BusinessEntity> .
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?startDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxEndDate < ?minStartDate)
# }

# %%
# Populate shacl SHACL shape with query generated from LLM
shacl_shape = f'''
@prefix sh: <http://www.w3.org/ns/shacl#> .
@prefix gr: <http://purl.org/goodrelations/v1#> .
@prefix pco: <http://purl.org/procurement/public-contracts#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .

<#BusinessLicenseContractShape> a sh:NodeShape ;
    sh:targetClass gr:BusinessEntity ;
    sh:message "The newest license end date must not be before the oldest contract start date." ;
    sh:sparql [
        a sh:SPARQLConstraint ;
        sh:message "The newest license end date must not be before the oldest contract start date." ;
        sh:select \"\"\" {sparql_query}\"\"\" ;
    ] .
'''
print(shacl_shape)
# Out:
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix gr: <http://purl.org/goodrelations/v1#> .
# @prefix pco: <http://purl.org/procurement/public-contracts#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <#BusinessLicenseContractShape> a sh:NodeShape ;
#     sh:targetClass gr:BusinessEntity ;
#     sh:message "The newest license end date must not be before the oldest contract start date." ;
#     sh:sparql [
#         a sh:SPARQLConstraint ;
#         sh:message "The newest license end date must not be before the oldest contract start date." ;
#         sh:select """ SELECT ?this ?maxEndDate ?minStartDate WHERE {
#   {
#     SELECT ?this (MAX(?endDate) AS ?maxEndDate) WHERE {
#       ?this a <http://purl.org/goodrelations/v1#BusinessEntity> .
#       ?this <http://purl.org/goodrelations/v1#hasLicense> ?license .
#       ?license <http://purl.org/procurement/public-contracts#actualEndDate> ?endDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?startDate) AS ?minStartDate) WHERE {
#       ?this a <http://purl.org/goodrelations/v1#BusinessEntity> .
#       ?contract <http://purl.org/procurement/public-contracts#bidder> ?this .
#       ?contract <http://purl.org/procurement/public-contracts#startDate> ?startDate .
#     } GROUP BY ?this
#   }
#   FILTER(?maxEndDate < ?minStartDate)
# }""" ;
#     ] .

# %%
# Parse shacl data
g.parse(data=shacl_shape, format="turtle")
# Out:
# <Graph identifier=N4f782c2d4fab4e02b97b80c18a17674f (<class 'rdflib.graph.Graph'>)>

# %%
# Perform validation
r = validate(g,
      shacl_graph=None,
      ont_graph=None,
      inference='rdfs',
      abort_on_first=False,
      allow_infos=True,
      allow_warnings=True,
      meta_shacl=False,
      advanced=False,
      js=False,
      debug=False)
conforms, results_graph, results_text = r

# %%
print(results_text)
# Out:
# Validation Report
# Conforms: False
# Results (13):
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.
# Constraint Violation in SPARQLConstraintComponent (http://www.w3.org/ns/shacl#SPARQLConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: <file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape>
# 	Focus Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420>
# 	Value Node: <http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420>
# 	Source Constraint: [ rdf:type sh:SPARQLConstraint ; sh:message Literal("The newest license end date must not be before the oldest contract start date.") ; sh:select Literal(" SELECT ?this ?newestLicenseEndDate ?oldestContractStartDate WHERE {
#   {
#     SELECT ?this (MAX(?licenseEndDate) AS ?newestLicenseEndDate) WHERE {
#       ?this a gr:BusinessEntity .
#       ?this gr:hasLicense ?license .
#       ?license pco:actualEndDate ?licenseEndDate .
#     } GROUP BY ?this
#   }
#   {
#     SELECT ?this (MIN(?contractStartDate) AS ?oldestContractStartDate) WHERE {
#       ?contract pco:bidder ?this .
#       ?contract pco:startDate ?contractStartDate .
#     } GROUP BY ?this
#   }
#   FILTER(?newestLicenseEndDate < ?oldestContractStartDate)
# }") ]
# 	Message: The newest license end date must not be before the oldest contract start date.

# %% [markdown]
# # Langraph React Agent

# %%
# Trasform SHACL-validation graph into a JSON
from collections import defaultdict
import json

def parse_shacl_result(report: Graph):
    grouped_violations = defaultdict(list)

    for result in report.subjects(RDF.type, SH.ValidationResult):
        focus_node = str(report.value(result, SH.focusNode))
        path = str(report.value(result, SH.resultPath)) if report.value(result, SH.resultPath) else None
        message = str(report.value(result, SH.resultMessage))
        severity = str(report.value(result, SH.resultSeverity)).split("#")[-1]
        source_shape = str(report.value(result, SH.sourceShape)) if report.value(result, SH.sourceShape) else None

        # Create a group key excluding the focus_node
        key = json.dumps({
            "path": path,
            "message": message,
            "severity": severity,
            "source_shape": source_shape
        }, sort_keys=True)

        grouped_violations[key].append(focus_node)

    # Format the grouped output
    compressed_output = []
    for key_str, focus_nodes in grouped_violations.items():
        common = json.loads(key_str)
        compressed_output.append({
            "common": common,
            "focus_nodes": focus_nodes
        })

    return compressed_output

# %%
@tool
def generate_sparql_query(rdf_schema: str, message: str):
    """
    Generates a SPARQL query based on the RDF schema and a message describing the validation.
    
    Expects a dictionary with two keys:
      - 'rdf_schema': a string with RDF prefixes and assumptions
      - 'message': a string describing the rule to implement
    Returns the SPARQL query string.
    """
    
    if not rdf_schema or not message:
        return "Error: 'rdf_schema' and 'message' must be provided."

    prompt = f"""
        You are an expert in SHACL and SPARQL.

        Given the following RDF schema (Turtle format):
        {rdf_schema}

        And the following task description:
        "{message}"

        Write only the SPARQL SELECT query that retrieves the described results.
        Do not include any explanations, comments, SHACL syntax, sparql or RDF prefixes.
        Your response must start directly with SELECT and include only the query body.
        Show the generated query.
        """

    return prompt

@tool
def run_shacl_validation(unused : str):
    """Process and report SHACL validation results from a structured representation of JSON data"""
    graph_data = parse_shacl_result(results_graph)
    graph_data_str = json.dumps(graph_data, indent=2)
    return graph_data_str

@tool
def get_context_from_configuration_and_query_neo4j(nodes_with_issues: list):
    """
    For each node, fetch actual related context from Neo4j using the configured Cypher queries.
    Returns real query results.
    """
    object_property_mappings = {
        "HAS_VENDOR": {
            "dst_uri": "http://purl.org/goodrelations/v1#BusinessEntity",
            "query": """MATCH path=(c:Contract)<-[:INCLUDED_IN_CONTRACT]-(:ContractRecord)-[:HAS_VENDOR]->(contractOrg:Organization)-[:BELONGS_TO_ORG_GROUP]->(o:OrganizationGroup)
                        WHERE elementId(o) = $node_id
                        RETURN DISTINCT path"""
        },
        "HAS_LICENSE": {
            "dst_uri": "http://purl.org/goodrelations/v1#BusinessEntity",
            "query": """MATCH path=(l:LicenseRecord)<-[:ORG_HAS_LICENSE]-(licenseOrg:Organization)-[:BELONGS_TO_ORG_GROUP]->(o:OrganizationGroup)
                        WHERE elementId(o) = $node_id
                        RETURN DISTINCT path"""
        }
    }

    enriched_results = []
    with neo4j_graph._driver.session() as session:
        for full_uri in nodes_with_issues:
            # Safely extract node_id
            if isinstance(full_uri, dict) and "focus_node" in full_uri:
                node_id = full_uri["focus_node"].split("/")[-1]
            elif isinstance(full_uri, str):
                node_id = full_uri.split("/")[-1]
            else:
                continue  # or raise an error

            context = {"node": node_id, "results": []}
            for mapping_name, mapping in object_property_mappings.items():
                query = mapping["query"]
                result = session.run(query, node_id=node_id)
                context["results"].append({
                    "mapping": mapping_name,
                    "query": query,
                    "data": [r.data() for r in result]
                })

            enriched_results.append(context)
    return enriched_results


tools = [generate_sparql_query, run_shacl_validation, get_context_from_configuration_and_query_neo4j]

# %%
from langgraph.prebuilt import create_react_agent

def explain_shacl_issues(llm, tools):
    """
    Run a LangGraph agent to summarize and explain SHACL validation results,
    including deeper insights via Cypher queries.
    
    Parameters:
        llm: The language model instance.
        tools: List of tools including any CypherQuery tool needed.
    
    Returns:
        The explanation string from the agent's final message.
    """

    # System message (persona and scope)
    system_message = (
        "You are helpful assistant that it is able to generate SPARQL query for RDF validation."
        "You are a helpful assistant who reports SHACL validation issues and explains them clearly. "
        "You have access to context through Cypher queries and can analyze ContractRecord and LicenseRecord details."
    )

    # Build the LangGraph REAct-style agent
    langgraph_agent_executor = create_react_agent(llm, tools, prompt=system_message)
    
    # Structured, improved prompt
    base_query = (
        f""" "Please perform the following:\n"
        "0. Based on the RDF schema and a message of the validation goal, generate a SPARQL query for SHACL validation. {rdf_schema}, {message}\n"
        "1. Run the SHACL validation and summarize the SHACL validation issues.\n"
        "2. Explain how each issue can be fixed.\n"
        "3. List the id of all the affected nodes.\n"
        "4. For each node:\n"
        "   a. Execute Cypher query on the Neo4j database to gather additional details.\n"
        "   b. Use the results to expand on why the issue was triggered.\n"
        "5. Prioritize `ContractRecord` and `LicenseRecord` details and the names of `contractOrg` and `licenseOrg`. "
        "Pay special attention to relevant date fields and information that helps explain the reason for the validation error.\n\n" """
    )

    # Invoke the agent
    print("---DEBUGGING")
    for step in langgraph_agent_executor.stream({"messages": [("human", base_query)]}):
        print(step)
    
    print("---FINAL VERSION")
    response = langgraph_agent_executor.invoke({"messages": [("human", base_query)]})
    return response["messages"][-1].content

# %%
response = explain_shacl_issues(llm=llm, tools=tools)
print(response)
# Out:
# ---DEBUGGING
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Wo7EUrihwrIRQZI4fRi99Jr6', 'function': {'arguments': '{"unused":""}', 'name': 'run_shacl_validation'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 265, 'total_tokens': 282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_79b79be41f', 'id': 'chatcmpl-BRBZ8olKXtviYbaei5wD7weSiVLe9', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d7c8cdab-42e4-4dfc-a91c-d055cc2d272d-0', tool_calls=[{'name': 'run_shacl_validation', 'args': {'unused': ''}, 'id': 'call_Wo7EUrihwrIRQZI4fRi99Jr6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 265, 'output_tokens': 17, 'total_tokens': 282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# {'tools': {'messages': [ToolMessage(content='[\n  {\n    "common": {\n      "message": "The newest license end date must not be before the oldest contract start date.",\n      "path": null,\n      "severity": "Violation",\n      "source_shape": "file:///Users/giuseppefutia/Desktop/code/klab/factory/chicago/#BusinessLicenseContractShape"\n    },\n    "focus_nodes": [\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214",\n      "http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420"\n    ]\n  }\n]', name='run_shacl_validation', id='a4ddd524-2dcb-4dda-a8fd-3a0771fe1624', tool_call_id='call_Wo7EUrihwrIRQZI4fRi99Jr6')]}}
# {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_JZ5vW8DwzuAye4xUg7EIGSVD', 'function': {'arguments': '{"nodes_with_issues":["http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214","http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420"]}', 'name': 'get_context_from_configuration_and_query_neo4j'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 623, 'prompt_tokens': 998, 'total_tokens': 1621, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_79b79be41f', 'id': 'chatcmpl-BRBZ9esrLdDWV5hVYUYuKLdPNha4Q', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6d902d90-164f-48ba-b813-3e2589845221-0', tool_calls=[{'name': 'get_context_from_configuration_and_query_neo4j', 'args': {'nodes_with_issues': ['http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214', 'http://purl.org/goodrelations/v1#BusinessEntity/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420']}, 'id': 'call_JZ5vW8DwzuAye4xUg7EIGSVD', 'type': 'tool_call'}], usage_metadata={'input_tokens': 998, 'output_tokens': 623, 'total_tokens': 1621, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# {'tools': {'messages': [ToolMessage(content='[{"node": "4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361", "results": [{"mapping": "HAS_VENDOR", "query": "MATCH path=(c:Contract)<-[:INCLUDED_IN_CONTRACT]-(:ContractRecord)-[:HAS_VENDOR]->(contractOrg:Organization)-[:BELONGS_TO_ORG_GROUP]->(o:OrganizationGroup)\\n                        WHERE elementId(o) = $node_id\\n                        RETURN DISTINCT path", "data": [{"path": [{"names": ["PARKING METER - YOUTH SERVICES"], "endDate": "2013-12-31", "name": "PARKING METER - YOUTH SERVICES", "id": "27350", "startDate": "2013-01-01"}, "INCLUDED_IN_CONTRACT", {"specificationId": "112464", "amount": 40000.0, "approvalDate": "01/17/2013", "pdfFile": "http://ecm.cityofchicago.org/eSMARTContracts/service/DPSWebDocumentViewer?sid=ESMART&id={1F9D2D8C-7F93-411B-B172-3B47D54E7E16}", "endDate": "12/31/2013", "name": "PARKING METER - YOUTH SERVICES", "contractId": "27350", "vendorId": "36517125L", "id": 164310, "source": "CONTRACTS", "startDate": "01/01/2013"}, "HAS_VENDOR", {"addresses": ["1310 E 75TH ST"], "componentId": 30529, "names": ["JOYOUS YEARS YOUTH EMPOWERMENT PROGRAM (JYYEP)"], "addressCities": ["CHICAGO"], "name": "JOYOUS YEARS YOUTH EMPOWERMENT PROGRAM (JYYEP)", "addressPostalCodes": ["60619"], "id": "36517125L", "source": "CONTRACTS", "addressStates": ["IL"]}, "BELONGS_TO_ORG_GROUP", {"names": ["JOYOUS YEARS YOUTH EMPOWERMENT PROGRAM (JYYEP)", "JOYOUS YEARS"], "sources": ["CONTRACTS", "LICENSES"], "name": "JOYOUS YEARS", "ids": ["36517125L", "281843"], "clusterId": 30529}]}]}, {"mapping": "HAS_LICENSE", "query": "MATCH path=(l:LicenseRecord)<-[:ORG_HAS_LICENSE]-(licenseOrg:Organization)-[:BELONGS_TO_ORG_GROUP]->(o:OrganizationGroup)\\n                        WHERE elementId(o) = $node_id\\n                        RETURN DISTINCT path", "data": [{"path": [{"address": "1310 E 75TH ST", "code": 1010, "endDate": "10/15/2010", "latitude": 41.758816119, "businessName": "JOYOUS YEARS", "businessId": 281843, "addressState": "IL", "source": "LICENSES", "addressPostalCode": "60619", "number": 1597041.0, "license_id": 1925234, "name": "JOYOUS YEARS", "siteNumber": 1, "id": 1137867, "startDate": "10/16/2008", "addressCity": "CHICAGO", "status": "AAI", "longitude": -87.592779654}, "ORG_HAS_LICENSE", {"addresses": ["1310 E 75TH ST"], "componentId": 30529, "names": ["JOYOUS YEARS"], "otherNames": ["JOYOUS YEARS"], "addressCities": ["CHICAGO"], "name": "JOYOUS YEARS", "addressPostalCodes": ["60619"], "id": 281843, "source": "LICENSES", "addressStates": ["IL"]}, "BELONGS_TO_ORG_GROUP", {"names": ["JOYOUS YEARS YOUTH EMPOWERMENT PROGRAM (JYYEP)", "JOYOUS YEARS"], "sources": ["CONTRACTS", "LICENSES"], "name": "JOYOUS YEARS", "ids": ["36517125L", "281843"], "clusterId": 30529}]}, {"path": [{"address": "1310 E 75TH ST", "code": 1010, "endDate": "11/15/2005", "latitude": 41.758816119, "businessName": "JOYOUS YEARS", "businessId": 281843, "addressState": "IL", "source": "LICENSES", "addressPostalCode": "60619", "number": 1597041.0, "license_id": 1597041, "name": "JOYOUS YEARS", "siteNumber": 1, "id": 1247186, "startDate": "06/07/2005", "addressCity": "CHICAGO", "status": "AAI", "longitude": -87.592779654}, "ORG_HAS_LICENSE", {"addresses": ["1310 E 75TH ST"], "componentId": 30529, "names": ["JOYOUS YEARS"], "otherNames": ["JOYOUS YEARS"], "addressCities": ["CHICAGO"], "name": "JOYOUS YEARS", "addressPostalCodes": ["60619"], "id": 281843, "source": "LICENSES", "addressStates": ["IL"]}, "BELONGS_TO_ORG_GROUP", {"names": ["JOYOUS YEARS YOUTH EMPOWERMENT PROGRAM (JYYEP)", "JOYOUS YEARS"], "sources": ["CONTRACTS", "LICENSES"], "name": "JOYOUS YEARS", "ids": ["36517125L", "281843"], "clusterId": 30529}]}, {"path": [{"address": "1310 E 75TH ST", "code": 1010, "endDate": "11/15/2006", "latitude": 41.758816119, "businessName": "JOYOUS YEARS", "businessId": 281843, "addressState": "IL", "source": "LICENSES", "addressPostalCode": "60619", "number": 1597041.0, "license_id": 1642110, "name": "JOYOUS YEARS", "sit ...
# {'agent': {'messages': [AIMessage(content='Summary of SHACL Validation Issue:\n- The validation rule violated is: "The newest license end date must not be before the oldest contract start date."\n- This means for each organization group, the latest license end date should be on or after the earliest contract start date.\n- The issue affects 13 organization groups (nodes) identified by their element IDs.\n\nAffected Nodes (Organization Groups):\n1. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361\n2. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344\n3. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645\n4. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998\n5. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803\n6. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893\n7. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112\n8. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236\n9. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645\n10. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773\n11. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557\n12. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214\n13. 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420\n\nExplanation and Fix for the Issue:\n- The SHACL rule expects that for each organization group, the latest license end date should be on or after the earliest contract start date.\n- The violation indicates that for these organization groups, the latest license end date is earlier than the earliest contract start date.\n- To fix this issue:\n  - Review the license records and contract records for each organization group.\n  - Ensure that the license end dates cover the period of the contracts, i.e., the license end date should be extended or updated to be on or after the earliest contract start date.\n  - Alternatively, adjust contract start dates if they are incorrect or if contracts should not exist without a valid license covering their period.\n\nDetailed Context for Each Node (Prioritized Contract and License Details):\n\n1. Node: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361\n   - ContractOrg: JOYOUS YEARS YOUTH EMPOWERMENT PROGRAM (JYYEP)\n   - Contracts: One contract "PARKING METER - YOUTH SERVICES" from 2013-01-01 to 2013-12-31\n   - Licenses: Multiple licenses for JOYOUS YEARS with end dates ranging from 2005 to 2010, latest license end date 2010-10-15\n   - Issue: The latest license end date (2010-10-15) is before the contract start date (2013-01-01).\n\n2. Node: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344\n   - ContractOrg: COURT THEATRE FUND\n   - Contracts: Multiple contracts from 2008 to 2023, earliest contract start date 2008-01-01\n   - Licenses: One license with end date 2003-08-15\n   - Issue: The latest license end date (2003-08-15) is before the earliest contract start date (2008-01-01).\n\n3. Node: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645\n   - ContractOrg: CHICAGO KIDS COMPANY\n   - Contracts: Multiple contracts from 2017 to 2023, earliest contract start date 2017-01-01\n   - Licenses: Licenses with end dates around 2003 to 2006\n   - Issue: Latest license end date is before earliest contract start date.\n\n4. Node: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998\n   - ContractOrg: RICHARD HUNT\n   - Contracts: Contract from 2014-12-01 to 2016-04-15\n   - Licenses: Licenses with end dates 2004 and 2005\n   - Issue: Latest license end date (2005) is before contract start date (2014).\n\n5. Node: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803\n   - ContractOrg: BLAIR THOMAS & COMPANY\n   - Contracts: Multiple contracts from 2014 to 2023, earliest contract start date 2014-12-01\n   - Licenses: Licenses with end dates from 2003 to 2012\n   - Issue: Latest license end date (2012) is before earliest contract start date (2014).\n\n6. Node: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893\n   - ContractOrg: WICKER PARK BUCKTOWN CHAMBER OF COMMERCE\n   - Contracts: Contracts from 2021 to 2023\n   - Licenses: Licenses with end dates from 2010 to 2019\n   - Issue: Latest license end date (2019) is before earliest ...
# ---FINAL VERSION
# Summary of SHACL Validation Issue:
# - Issue: "The newest license end date must not be before the oldest contract start date."
# - Severity: Violation
# - Source Shape: BusinessLicenseContractShape
# - Affected Nodes: 13 nodes identified by their IDs.
#
# Explanation of the Issue:
# This validation error occurs because for each organization group (node), the latest license end date is earlier than the earliest contract start date. This means there is a temporal inconsistency where the licenses have expired before the contracts started, which is logically incorrect.
#
# How to Fix:
# - Ensure that the license periods cover or extend beyond the contract periods.
# - Update license records to have end dates that are on or after the earliest contract start date.
# - Alternatively, adjust contract start dates to be on or after the latest license end date if appropriate.
#
# Affected Nodes and Details:
#
# 1. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323361
#    - ContractOrg: JOYOUS YEARS YOUTH EMPOWERMENT PROGRAM (JYYEP)
#    - LicenseOrg: JOYOUS YEARS
#    - Contracts start from 2013-01-01 to 2013-12-31.
#    - Latest License end date: 10/15/2010 (licenses end before contract starts).
#    - Reason: License expired in 2010, but contract started in 2013.
#
# 2. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2317344
#    - ContractOrg: COURT THEATRE FUND
#    - LicenseOrg: COURT THEATRE FUND
#    - Contracts start from 2008-01-01 to 2023-12-31.
#    - Latest License end date: 08/15/2003 (licenses end before contract starts).
#    - Reason: License expired in 2003, but contracts start from 2008 onwards.
#
# 3. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2316645
#    - ContractOrg: CHICAGO KIDS COMPANY
#    - LicenseOrg: CHICAGO KIDS COMPANY
#    - Contracts start from 2017-01-01 to 2023-12-31.
#    - Latest License end date: 08/15/2006 (licenses end before contract starts).
#    - Reason: License expired in 2006, but contracts start from 2017 onwards.
#
# 4. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322998
#    - ContractOrg: RICHARD HUNT
#    - LicenseOrg: RICHARD HUNT
#    - Contracts start from 2004-12-01 to 2016-04-15.
#    - Latest License end date: 05/15/2005 (licenses end before contract starts).
#    - Reason: License expired in 2005, but contract started in 2004 (some overlap but license end date is before contract end date).
#
# 5. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319803
#    - ContractOrg: BLAIR THOMAS & COMPANY
#    - LicenseOrg: BLAIR THOMAS & COMPANY
#    - Contracts start from 2014-12-01 to 2023-12-31.
#    - Latest License end date: 08/15/2008 (licenses end before contract starts).
#    - Reason: License expired in 2008, but contracts start from 2014 onwards.
#
# 6. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2318893
#    - ContractOrg: WICKER PARK BUCKTOWN CHAMBER OF COMMERCE
#    - LicenseOrg: THE WICKER PARK & BUCKTOWN CHAMBER OF COMMERCE
#    - Contracts start from 2021-01-01 to 2023-12-31.
#    - Latest License end date: 07/26/2015 (licenses end before contract starts).
#    - Reason: License expired in 2015, but contracts start from 2021 onwards.
#
# 7. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321112
#    - ContractOrg: DOCK'S
#    - LicenseOrg: DOCK'S GREAT FISH, INC
#    - Contracts start from 2003-06-27 to 2007-07-08.
#    - Latest License end date: 05/15/2003 (licenses end before contract starts).
#    - Reason: License expired in 2003, but contract started in 2003 (license end date before contract start date).
#
# 8. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2322236
#    - ContractOrg: STAGE LEFT THEATRE,INC
#    - LicenseOrg: Stage Left, Inc.
#    - Contracts start date: 2016-07-01.
#    - Latest License end date: 02/15/2003 (licenses end before contract starts).
#    - Reason: License expired in 2003, but contract started in 2016.
#
# 9. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2320645
#    - ContractOrg: MICHELLE MCFARLAND-MCDANIELS
#    - LicenseOrg: MICHELLE N MCFARLAND
#    - Contracts start date: 2012-01-01.
#    - Latest License end date: 11/15/2004 (licenses end before contract starts).
#    - Reason: License expired in 2004, but contract started in 2012.
#
# 10. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319773
#     - ContractOrg: VANDERCOOK COLLEGE OF MUSIC
#     - LicenseOrg: VANDERCOOK COLLEGE OF MUSIC
#     - Contracts start from 2022-01-01 to 2023-12-31.
#     - Latest License end date: 08/15/2016 (licenses end before contract starts).
#     - Reason: License expired in 2016, but contracts start from 2022 onwards.
#
# 11. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2319557
#     - ContractOrg: LEAH S COWEN
#     - LicenseOrg: LEAH SHOSHANAH COWEN
#     - Contracts start date: 2022-01-01.
#     - Latest License end date: 06/15/2019 (licenses end before contract starts).
#     - Reason: License expired in 2019, but contract started in 2022.
#
# 12. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2321214
#     - ContractOrg: MARTHA SANDERS
#     - LicenseOrg: MARTHA E SANDERS
#     - Contracts start from 2012-01-01 to 2019-12-31.
#     - Latest License end date: 08/15/2005 (licenses end before contract starts).
#     - Reason: License expired in 2005, but contracts start from 2012 onwards.
#
# 13. Node ID: 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:2323420
#     - ContractOrg: KARLA LOVE
#     - LicenseOrg: KARLA LOVE-DAVIS
#     - Contracts start date: 2011-01-25.
#     - Latest License end date: 12/15/2008 (licenses end before contract starts).
#     - Reason: License expired in 2008, but contract started in 2011.
#
# Summary:
# All affected nodes have a mismatch where the latest license end date is before the earliest contract start date, causing the SHACL validation violation. The fix is to update license end dates to cover the contract periods or adjust contract start dates accordingly.
#
# If you want, I can assist in generating a report or suggest specific data updates for each node.
