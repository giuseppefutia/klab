# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import configparser

from langchain_core.tools import tool
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# Load helper functions and setup
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(project_root)

from analysis.chicago.setup import setup_llm_and_graph
from analysis.chicago.utils import run_validation_pipeline, parse_shacl_result, process_agent_step
from analysis.chicago.conflict_of_interest.prompt import SHACL_PROMPTS, AGENT_PROMPTS
from analysis.chicago.conflict_of_interest.conflict_utils import run_explainability_query
from yfiles_jupyter_graphs_for_neo4j import Neo4jGraphWidget
from database.neo4j_db import Neo4jGraphDB

llm, neo4j_graph = setup_llm_and_graph()

# %%
# Load configuration, database, and visualization
config = configparser.ConfigParser()
config.read('../../config.ini')
neo4j_graph = Neo4jGraphDB()
driver = Neo4jGraphDB()._driver
jg = Neo4jGraphWidget(driver)

# %% [markdown]
# # SHACL Validation Test

# %%
# Test the generation of the SHACL rules
rdf_schema = SHACL_PROMPTS["rdf_schema"]
message = SHACL_PROMPTS["message"]

prompt = PromptTemplate(
    input_variables=["message", "rdf_schema"],
    template=SHACL_PROMPTS["template"]
)

chain = prompt | llm | StrOutputParser()
shacl_shape = chain.invoke({"message": message, "rdf_schema": rdf_schema})
print(shacl_shape)
# Out:
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix schema: <https://schema.org/> .
#
# <#DisconnectedPeopleShape> a sh:NodeShape ;
#     sh:targetClass foaf:Person ;
#     sh:property [
#         sh:path schema:relatedTo ;
#         sh:maxCount 0 ;
#         sh:message "A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest."
#     ] .

# %%
conforms, results_graph, results_text = run_validation_pipeline("../../data/chicago/conflict.ttl", shacl_shape)
# Out:
# Data Graph has 388010 statements.
# SHACL Graph has 6 statements.

# %%
print(results_text)
# Out:
# Validation Report
# Conforms: False
# Results (72):
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:450997>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:520260>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:351551>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:436184>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:404687>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:348477>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:504295>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:358186>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:486091>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:392989>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:363805>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:395069>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:479174>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:416243>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:411439>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:516295>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:352710>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:513541>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:402103>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:371079>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:364707>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:493644>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:381604>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:358638>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:450412>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:493531>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:498621>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:363641>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:364950>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:371697>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:414409>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:382863>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:441775>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:396660>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:448863>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:412796>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:416962>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:387098>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:371399>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:345242>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:492537>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:390856>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:425038>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:388190>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:355708>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:394013>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:457624>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:378743>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:349922>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:414742>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:345249>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:353022>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:364763>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:371940>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367419>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:348684>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:418894>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:422268>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:509825>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:462018>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:347932>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:372499>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:365973>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:430027>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:489168>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:401259>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:438508>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:344706>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:478830>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:373752>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:366431>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.") ; sh:path schema:relatedTo ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:375001>
# 	Result Path: schema:relatedTo
# 	Message: A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.

# %% [markdown]
# # LangGraph React Agent

# %%
import json

@tool
def generate_shacl_shape(rdf_schema: str, message: str):
    """
    Generates a SHACL NodeShape based on the RDF schema and a message describing the validation.

    Expects two parameters:
      - 'rdf_schema': a string with RDF prefixes and assumptions
      - 'message': a string describing the SHACL rule to implement
    Returns the SHACL NodeShape in Turtle syntax as a string.
    """

    if not rdf_schema or not message:
        return "Error: 'rdf_schema' and 'message' must be provided."

    prompt = SHACL_PROMPTS["template"]

    return prompt

@tool
def run_shacl_validation(unused: str):
    """Process and report SHACL validation results from a structured representation of Graph data"""
    graph_data = parse_shacl_result(results_graph)
    graph_data_str = json.dumps(graph_data, indent=2)
    return graph_data_str

@tool
def get_context_from_neo4j(nodes_with_issues: list):
    """
    For each node, fetch actual related context from Neo4j using the configured Cypher queries.
    Returns real query results.
    """

    return run_explainability_query(neo4j_graph, nodes_with_issues)


tools = [generate_shacl_shape, run_shacl_validation, get_context_from_neo4j]

# %%
from langgraph.prebuilt import create_react_agent

def explain_shacl_issues(llm, tools):
    """
    Run a LangGraph agent to summarize and explain SHACL validation results,
    including deeper insights via Cypher queries.
    
    Parameters:
        llm: The language model instance.
        tools: List of tools including any CypherQuery tool needed.
    
    Returns:
        The explanation string from the agent's final message.
    """

    # System message (persona and scope)
    system_message = (
        "You are a helpful assistant who reports SHACL validation issues and explains them clearly. "
        "You have access to context through Cypher queries and can analyze ContractRecord and LicenseRecord details."
    )

    # Build the LangGraph REAct-style agent
    langgraph_agent_executor = create_react_agent(llm, tools, prompt=system_message)

    # Structured, improved prompt
    base_query = AGENT_PROMPTS["explain"]

    # Invoke the agent
    print("---DEBUGGING")
    for step in langgraph_agent_executor.stream({"messages": [("human", base_query)]}):
        process_agent_step(step)
    
    print("---FINAL VERSION")
    response = langgraph_agent_executor.invoke({"messages": [("human", base_query)]})
    return response["messages"][-1].content

# %%
response = explain_shacl_issues(llm=llm, tools=tools)
print(response)
# Out:
# ---DEBUGGING
#
# === Agent Step ===
#
# 🔧 Tool Call: generate_shacl_shape
# 🧾 Arguments:
#   - rdf_schema: @prefix schema: <http://schema.org/> .
# @prefix ex: <http://example.org/> .
#
# ex:Person a rdfs:Class ;...
#   - message: Validate that no two people connected by schema:relatedTo have the same surname to avoid potential c...
#
# 🔧 Tool Call: run_shacl_validation
# 🧾 Arguments:
#   - unused:
#
# === Tool Results ===
#
# 🛠️ Tool Name: generate_shacl_shape
# 🆔 Tool Call ID: call_p4F9EVaaO2QUhb2R9WxK6on4
# 📄 Content:
#
#         You are an expert in SHACL and RDF validation.
#
#         Given the following RDF schema:
#         {rdf_schema}
#
#         And the following instruction:
#         "{message}"
#
#         Write only the SHACL NodeShape in Turtle syntax.
#
#         Important formatting rules:
#         - Use exactly the NodeShape URI <#DisconnectedPeopleShape>.
#         - Include all necessary prefixes.
#         - Do NOT add any ```turtle, ``` or other code block markers.
#         - Do NOT add any extra text, explanation, or comments.
#         - Start directly with prefixes, followed by the SHACL shape.
#         - Output must be pure Turtle syntax, as it would appear inside an RDF file.
#
#         Only output the pure content. Nothing else.
#
#
# 🛠️ Tool Name: run_shacl_validation
# 🆔 Tool Call ID: call_Li42CKsEpaVrPhjmkvCCwPBD
# 📄 Content:
# [
#   {
#     "common": {
#       "message": "A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest.",
#       "path": "https://schema.org/relatedTo",
#       "severity": "Violation",
#       "source_shape": "n486d90d9f9be4d5cb7cf6d2d5349e2a1b1"
#     },
#     "focus_nodes": [
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:450997",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:520260",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:351551",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:436184",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:404687",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:348477",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:504295",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:358186",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:486091",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:392989",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:363805",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:395069",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:479174",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:416243",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:411439",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:516295",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:352710",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:513541",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:402103",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:371079",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:364707",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:493644",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:381604",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:358638",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:450412",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:493531",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:498621",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:363641",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:364950",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:371697",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:414409",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:382863",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:441775",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:396660",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:448863",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:412796",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:416962",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:387098",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:371399",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:345242",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:492537",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:390856",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:425038",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:388190",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:355708",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:394013",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:457624",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:378743",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:349922",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:414742",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:345249",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:353022",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:364763",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:371940",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367419",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:348684",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:418894",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:422268",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:509825",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:462018",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:347932",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:372499",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:365973",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:430027",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:489168",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:401259",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:438508",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:344706",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:478830",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:373752",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:366431",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:375001"
#     ]
#   }
# ]
#
# === Agent Step ===
# ---FINAL VERSION
# 0. Generated SHACL NodeShape in Turtle syntax:
#
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix schema: <http://schema.org/> .
# @prefix ex: <http://example.org/> .
#
# <#DisconnectedPeopleShape> a sh:NodeShape ;
#     sh:targetClass ex:Person ;
#     sh:property [
#         sh:path schema:relatedTo ;
#         sh:message "A person must not be connected to another person via schema:relatedTo. It means a potential conflict of interest." ;
#         sh:severity sh:Violation ;
#         sh:not [
#             sh:property [
#                 sh:path schema:relatedTo ;
#                 sh:pattern "^.*\\s([^\\s]+)$" ; # Surname extraction pattern (last word)
#             ]
#         ] ;
#     ] .
#
# 1. SHACL validation issues found:
# - Multiple Person nodes are connected to other Person nodes via the schema:relatedTo property where the connected persons share the same surname. This indicates potential conflicts of interest.
#
# 2. Explanation and suggestions for each issue:
# a. Issue occurred because two different Person nodes are related via schema:relatedTo and they share the same surname, which may indicate a conflict of interest.
# b. To fix the issue, review the relationships and ensure that persons with the same surname are not connected in a way that creates a conflict of interest. If the relationship is valid, consider adding an exception or clarifying the relationship context.
#
# 3. List of affected RDF nodes (subjects):
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:450997
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:520260
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:351551
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:436184
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:404687
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:348477
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:504295
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:358186
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:486091
# - http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:392989
#
# 4. Context and expanded explanation for some affected nodes:
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:450997:
#   Persons: Joseph Reynolds (works for FIRE DEPARTMENT) and Justin L Reynolds (works for INDEPENDENT MECHANICAL INDUSTRIES, INC.)
#   Relationship: They share the same surname "Reynolds" and are connected via schema:relatedTo.
#   Contracts: Related to contract "CHILLER REPACEMENT" with amount $117,800.
#   Explanation: Joseph Reynolds works for a department that assigns contracts to organizations where Justin L Reynolds works. The shared surname and relationship indicate a potential conflict of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:520260:
#   Persons: Lemonte Booker (works for DEPT OF AVIATION) and Sherman S Booker (works for FIELD MUSEUM OF NATURAL HISTORY)
#   Relationship: Shared surname "Booker" and related via schema:relatedTo.
#   Contracts: License and concession agreements with amount $0.
#   Explanation: The connection between persons with the same surname working in different organizations related by contracts may indicate a conflict of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:351551:
#   Persons: Dylan Thomas (works for FIRE DEPARTMENT) and multiple persons with surname "Thomas" working for FREEWAY FORD-STERLING TRUCK SALES, INC.
#   Relationship: Shared surname "Thomas" and related via schema:relatedTo.
#   Contracts: Multiple contracts related to mass casualty incident response trucks and parts & repair services.
#   Explanation: The extensive relationships between persons named Thomas across departments and organizations with contract ties suggest potential conflicts of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:436184:
#   Persons: Jordan Taylor (works for FIRE DEPARTMENT) and multiple persons with surname "Taylor" working for ENVIRONMENTAL FUTURES INC.
#   Relationship: Shared surname "Taylor" and related via schema:relatedTo.
#   Contracts: Contract for bottleless water cooler with amount $975.
#   Explanation: The relationship between persons named Taylor in different organizations connected by contracts may indicate conflict of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:404687:
#   Persons: Linda King (works for FIRE DEPARTMENT and DEPT OF AVIATION) and multiple persons with surname "King" working for DEE JANITORIAL SUPPLY INC.
#   Relationship: Shared surname "King" and related via schema:relatedTo.
#   Contracts: Various contracts for vacuum cleaners and other supplies.
#   Explanation: The connection between persons named King in departments and organizations with contract relationships suggests potential conflict of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:348477:
#   Persons: Juan Aguilar (works for DEPT OF FLEET MGMT) and multiple persons with surname "Aguilar" working for CAR WASH PARTNERS INC.
#   Relationship: Shared surname "Aguilar" and related via schema:relatedTo.
#   Contracts: Multiple car washing services contracts.
#   Explanation: The relationship between persons named Aguilar in different organizations connected by contracts may indicate conflict of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:504295:
#   Persons: Kenneth W Aldridge (works for DEPT OF AVIATION) and Derrick Aldridge (works for ALDRIDGE ELECTRIC INC)
#   Relationship: Shared surname "Aldridge" and related via schema:relatedTo.
#   Contracts: Multiple contracts for airfield lighting infrastructure upgrades.
#   Explanation: The connection between persons named Aldridge in departments and organizations with contract ties suggests potential conflict of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:358186:
#   Persons: Lori Heather Mitchell (works for DEPT OF FAMILY AND SUPPORT SERVICES) and multiple persons with surname "Mitchell" working for PRIMO CENTER FOR WOMEN AND CHILDREN.
#   Relationship: Shared surname "Mitchell" and related via schema:relatedTo.
#   Contracts: Multiple contracts related to family and support services.
#   Explanation: The relationship between persons named Mitchell in different organizations connected by contracts may indicate conflict of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:486091:
#   Persons: Kathleen Anne Stringfellow (works for DEPT OF FLEET MGMT) and Vernon Stringfellow (works for ALLIED COLLISION INC)
#   Relationship: Shared surname "Stringfellow" and related via schema:relatedTo.
#   Contracts: Contracts for parts and services for city-owned autos and light trucks.
#   Explanation: The connection between persons named Stringfellow in departments and organizations with contract relationships suggests potential conflict of interest.
#
# - Node 4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:392989:
#   Persons: Charlie Banks (works for multiple departments) and multiple persons with surname "Banks" working for PRODUCTIONS DYNAMICS OF CHICAGO.
#   Relationship: Shared surname "Banks" and related via schema:relatedTo.
#   Contracts: Various contracts for communications, electrical supplies, and other services.
#   Explanation: The extensive relationships between persons named Banks across departments and organizations with contract ties suggest potential conflicts of interest.
#
# 5. Prioritized details about Person nodes and their Departments/Organizations:
#
# - Joseph Reynolds (FIRE DEPARTMENT) related to Justin L Reynolds (INDEPENDENT MECHANICAL INDUSTRIES, INC.)
# - Lemonte Booker (DEPT OF AVIATION) related to Sherman S Booker (FIELD MUSEUM OF NATURAL HISTORY)
# - Dylan Thomas (FIRE DEPARTMENT) related to multiple Thomases (FREEWAY FORD-STERLING TRUCK SALES, INC.)
# - Jordan Taylor (FIRE DEPARTMENT) related to multiple Taylors (ENVIRONMENTAL FUTURES INC)
# - Linda King (FIRE DEPARTMENT, DEPT OF AVIATION) related to multiple Kings (DEE JANITORIAL SUPPLY INC)
# - Juan Aguilar (DEPT OF FLEET MGMT) related to multiple Aguilars (CAR WASH PARTNERS INC.)
# - Kenneth W Aldridge (DEPT OF AVIATION) related to Derrick Aldridge (ALDRIDGE ELECTRIC INC)
# - Lori Heather Mitchell (DEPT OF FAMILY AND SUPPORT SERVICES) related to multiple Mitchells (PRIMO CENTER FOR WOMEN AND CHILDREN)
# - Kathleen Anne Stringfellow (DEPT OF FLEET MGMT) related to Vernon Stringfellow (ALLIED COLLISION INC)
# - Charlie Banks (multiple departments) related to multiple Banks (PRODUCTIONS DYNAMICS OF CHICAGO)
#
# Summary:
# The SHACL validation identified multiple Person nodes connected via schema:relatedTo where the connected persons share the same surname, indicating potential conflicts of interest. These persons often work in different departments and organizations that are contractually related, which raises concerns about impartiality and conflict of interest. It is recommended to review these relationships carefully and take appropriate actions to mitigate conflicts.

# %%
# Showing bridges between highly-connected records
jg.show_cypher("""
               MATCH 
                    path=(p2:Person)<-[:RECORD_RESOLVED_TO]-(:PersonRecord)
                    -[:WORKS_FOR_DEPARTMENT]->(dept1:Department)
                    -[:IS_SIMILAR_TO]->(dept2:Department)
                    -[:ASSIGNS_CONTRACT]->(:Contract)<-[:INCLUDED_IN_CONTRACT]-(c:ContractRecord)
                    -[:HAS_VENDOR]->(vendor1:Organization)
                    -[:BELONGS_TO_ORG_GROUP]->(orgGroup:OrganizationGroup)<-[:BELONGS_TO_ORG_GROUP]-
                    (vendor2:Organization)<-[:WORKS_FOR_ORG]-(p1:Person)
                WHERE 
                    (
                        elementId(p2) = "4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:492537 "OR 
                        elementId(p1) = "4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:492537"
                    )
                    AND vendor1 <> vendor2
                    AND p1 <> p2
                    AND toLower(p1.name) <> toLower(p2.name)
                    AND split(toLower(p1.name), " ")[-1] = split(toLower(p2.name), " ")[-1]
                RETURN path
                LIMIT 5
               """)
# Out:
# GraphWidget(layout=Layout(height='650px', width='100%'))
