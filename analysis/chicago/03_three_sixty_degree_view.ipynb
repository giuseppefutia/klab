# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

from langchain_core.tools import tool
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# Load helper functions and setup
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(project_root)

from analysis.chicago.setup import setup_llm_and_graph
from analysis.chicago.utils import run_validation_pipeline, parse_shacl_result, process_agent_step
from analysis.chicago.three_sixty_degree_view.prompt import SHACL_PROMPTS, AGENT_PROMPTS
from analysis.chicago.three_sixty_degree_view.three_sixty_utils import run_explainability_query

llm, neo4j_graph = setup_llm_and_graph()

# %% [markdown]
# # SHACL Validation Test

# %%
# Test the generation of the SHACL rules
rdf_schema = SHACL_PROMPTS["rdf_schema"]
message = SHACL_PROMPTS["message"]

prompt = PromptTemplate(
    input_variables=["message", "rdf_schema"],
    template=SHACL_PROMPTS["template"]
)

chain = prompt | llm | StrOutputParser()
shacl_shape = chain.invoke({"message": message, "rdf_schema": rdf_schema})
print(shacl_shape)
# Out:
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix pc: <http://purl.org/procurement/public-contracts#> .
#
# <#SuppliersShape> a sh:NodeShape ;
#     sh:targetClass foaf:Person ;
#     sh:property [
#         sh:path pc:hasSupplier ;
#         sh:maxCount 0 ;
#         sh:message "A person is associated to a contract via pc:hasSupplier."
#     ] .

# %%
conforms, results_graph, results_text = run_validation_pipeline("../../data/chicago/three_sixty.ttl", shacl_shape)
# Out:
# Data Graph has 25 statements.
# SHACL Graph has 6 statements.

# %%
print(results_text)
# Out:
# Validation Report
# Conforms: False
# Results (5):
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person is associated to a contract via pc:hasSupplier.") ; sh:path pc:hasSupplier ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472684>
# 	Result Path: pc:hasSupplier
# 	Message: A person is associated to a contract via pc:hasSupplier.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person is associated to a contract via pc:hasSupplier.") ; sh:path pc:hasSupplier ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:349922>
# 	Result Path: pc:hasSupplier
# 	Message: A person is associated to a contract via pc:hasSupplier.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person is associated to a contract via pc:hasSupplier.") ; sh:path pc:hasSupplier ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472207>
# 	Result Path: pc:hasSupplier
# 	Message: A person is associated to a contract via pc:hasSupplier.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person is associated to a contract via pc:hasSupplier.") ; sh:path pc:hasSupplier ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367528>
# 	Result Path: pc:hasSupplier
# 	Message: A person is associated to a contract via pc:hasSupplier.
# Constraint Violation in MaxCountConstraintComponent (http://www.w3.org/ns/shacl#MaxCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:maxCount Literal("0", datatype=xsd:integer) ; sh:message Literal("A person is associated to a contract via pc:hasSupplier.") ; sh:path pc:hasSupplier ]
# 	Focus Node: <http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367530>
# 	Result Path: pc:hasSupplier
# 	Message: A person is associated to a contract via pc:hasSupplier.

# %% [markdown]
# # LangGraph React Agent

# %%
import json

@tool
def generate_shacl_shape(rdf_schema: str, message: str):
    """
    Generates a SHACL NodeShape based on the RDF schema and a message describing the validation.

    Expects two parameters:
      - 'rdf_schema': a string with RDF prefixes and assumptions
      - 'message': a string describing the SHACL rule to implement
    Returns the SHACL NodeShape in Turtle syntax as a string.
    """

    if not rdf_schema or not message:
        return "Error: 'rdf_schema' and 'message' must be provided."

    prompt = SHACL_PROMPTS["template"]

    return prompt

@tool
def run_shacl_validation(unused: str):
    """Process and report SHACL validation results from a structured representation of Graph data"""
    graph_data = parse_shacl_result(results_graph)
    graph_data_str = json.dumps(graph_data, indent=2)
    return graph_data_str

@tool
def get_context_from_neo4j(nodes_with_issues: list):
    """
    For each node, fetch actual related context from Neo4j using the configured Cypher queries.
    Returns real query results.
    """

    return run_explainability_query(neo4j_graph, nodes_with_issues)


tools = [generate_shacl_shape, run_shacl_validation, get_context_from_neo4j]

# %%
from langgraph.prebuilt import create_react_agent

def explain_shacl_issues(llm, tools):
    """
    Run a LangGraph agent to summarize and explain SHACL validation results,
    including deeper insights via Cypher queries.
    
    Parameters:
        llm: The language model instance.
        tools: List of tools including any CypherQuery tool needed.
    
    Returns:
        The explanation string from the agent's final message.
    """

    # System message (persona and scope)
    system_message = (
        "You are a helpful assistant who reports SHACL validation issues and explains them clearly. "
        "You have access to context through Cypher queries and can analyze ContractRecord and LicenseRecord details."
    )

    # Build the LangGraph REAct-style agent
    langgraph_agent_executor = create_react_agent(llm, tools, prompt=system_message)

    # Structured, improved prompt
    base_query = AGENT_PROMPTS["explain"]

    # Invoke the agent
    print("---DEBUGGING")
    for step in langgraph_agent_executor.stream({"messages": [("human", base_query)]}):
        process_agent_step(step)
    
    print("---FINAL VERSION")
    response = langgraph_agent_executor.invoke({"messages": [("human", base_query)]})
    return response["messages"][-1].content

# %%
response = explain_shacl_issues(llm=llm, tools=tools)
print(response)
# Out:
# ---DEBUGGING
#
# === Agent Step ===
#
# 🔧 Tool Call: generate_shacl_shape
# 🧾 Arguments:
#   - rdf_schema: @prefix ex: <http://example.org/ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:Contra...
#   - message: Each Person must have at least one hasContract relationship to a ContractRecord with an amount great...
#
# 🔧 Tool Call: run_shacl_validation
# 🧾 Arguments:
#   - unused:
#
# === Tool Results ===
#
# 🛠️ Tool Name: generate_shacl_shape
# 🆔 Tool Call ID: call_IVgGEX0Nuyd1DjnJKTsJGvTC
# 📄 Content:
#
#         You are an expert in SHACL and RDF validation.
#
#         Given the following RDF schema:
#         {rdf_schema}
#
#         And the following instruction:
#         "{message}"
#
#         Write only the SHACL NodeShape in Turtle syntax.
#
#         Important formatting rules:
#         - Use exactly the NodeShape URI <#SuppliersShape>.
#         - Include all necessary prefixes.
#         - Do NOT add any ```turtle, ``` or other code block markers.
#         - Do NOT add any extra text, explanation, or comments.
#         - Start directly with prefixes, followed by the SHACL shape.
#         - Output must be pure Turtle syntax, as it would appear inside an RDF file.
#
#         Only output the pure content. Nothing else.
#
#
# 🛠️ Tool Name: run_shacl_validation
# 🆔 Tool Call ID: call_7sE6B64ZEd8Mjk9rmjYYeSbY
# 📄 Content:
# [
#   {
#     "common": {
#       "message": "A person is associated to a contract via pc:hasSupplier.",
#       "path": "http://purl.org/procurement/public-contracts#hasSupplier",
#       "severity": "Violation",
#       "source_shape": "n6dab372cb8944f1894bf838bc83b0b6eb1"
#     },
#     "focus_nodes": [
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472684",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:349922",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472207",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367528",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367530"
#     ]
#   }
# ]
#
# === Agent Step ===
#
# 🔧 Tool Call: run_shacl_validation
# 🧾 Arguments:
#   - unused:
#
# 🔧 Tool Call: get_context_from_neo4j
# 🧾 Arguments:
#   - nodes_with_issues: ['http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472684', 'http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:349922', 'http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472207', 'http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367528', 'http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367530']
#
# === Tool Results ===
#
# 🛠️ Tool Name: run_shacl_validation
# 🆔 Tool Call ID: call_O9tI9WynRZjFHWmnZJZZF4Jh
# 📄 Content:
# [
#   {
#     "common": {
#       "message": "A person is associated to a contract via pc:hasSupplier.",
#       "path": "http://purl.org/procurement/public-contracts#hasSupplier",
#       "severity": "Violation",
#       "source_shape": "n6dab372cb8944f1894bf838bc83b0b6eb1"
#     },
#     "focus_nodes": [
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472684",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:349922",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472207",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367528",
#       "http://xmlns.com/foaf/0.1/Person/4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:367530"
#     ]
#   }
# ]
#
# 🛠️ Tool Name: get_context_from_neo4j
# 🆔 Tool Call ID: call_jsrl4ugj9PcD7YmJgVgn1XBV
# 📄 Content:
# [{"node": "4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:472684", "results": [{"mapping": "IS_RELATED_TO", "query": "\n                MATCH (pr:PersonRecord)-[:RECORD_RESOLVED_TO]->(p:Person)\n                -[:WORKS_FOR_ORG]->(:Organization)\n                -[:BELONGS_TO_ORG_GROUP]->(:OrganizationGroup)<-[:BELONGS_TO_ORG_GROUP]-\n                (o:Organization)<-[:HAS_VENDOR]-(c:ContractRecord)-[:INCLUDED_IN_CONTRACT]->(x:Contract)\n\n                WHERE elementId(p) = $node_id\n                AND c.amount <> 0\n                WITH \n                p.name AS personName,\n                collect(DISTINCT pr.fullName) AS fullNames,\n                collect(DISTINCT o.name) AS orgNames,\n                collect(DISTINCT \n                    c.id + \" - \" + c.name + \" - Amount: \" + toString(c.amount) + \"$\"\n                ) AS contractRecordDetails,\n                toString(sum(DISTINCT c.amount)) + \"$\" AS totalAmount\n\n                RETURN \n                personName,\n                fullNames,\n                orgNames,\n                contractRecordDetails,\n                totalAmount\n                LIMIT 10\n            ", "data": [{"personName": "Sister Marie Valerie Chaillou", "fullNames": ["Sister Marie Valerie Chaillou"], "orgNames": ["FRATERNITE NOTRE DAME, INC"], "contractRecordDetails": ["194 - 2014 DELEGATE AWARD - Amount: 15000.0$", "2752 - ORIGINAL - Amount: -1734.5$", "2753 - ORIGINAL - Amount: -5366.1$", "7844 - ORIGINAL - Amount: 4000.0$", "7907 - ORIGINAL - Amount: -500.0$", "7910 - ORIGINAL - Amount: -3500.0$", "11382 - CDBG YOUTH DEVELOPMENT SERVICES - Amount: 25000.0$", "14005 - FY 00 CSBG YOUTH DEVELOPMENT SERVICES - Amount: 40000.0$", "38823 - ORIGINAL - Amount: -6873.1$", "41573 - ORIGINAL - Amount: -1835.4$", "43997 - ORIGINAL - Amount: -6955.3$", "115094 - FY '10 CDBG EMERGENCY FOOD - Amount: 25000.0$", "116306 - EMERGENCY FOOD/FEEDING PROGRAM - Amount: 25000.0$", "119265 - FY 04 CDBG YOUTH DEVELOPMENT - Amount: 20000.0$", "122818 - FY '09 CORP- YOUTH DEVELOPMENT - Amount: 20000.0$", "122836 - FY '07 CDBG YOUTH DEVELOPMENT - Amount: 30000.0$", "124768 - CORP - HUMAN SERVICES DELIVERY - Amount: 15000.0$", "125520 - FY '2009 EMERGENCY FOOD - Amount: 25000.0$", "127568 - 2011 EMERGENCY FOOD PROGRAM - CORPORATE - Amount: 25000.0$", "133716 - FY '2008 EMERGENCY FOOD - Amount: 50000.0$", "139284 - FY '06 - CDBG YOUTH DEVELOPMENT - Amount: 30000.0$", "142365 - FY 05 CDBG-YOUTH SERVICES - Amount: 20000.0$", "144494 - FY '11 CDBG YOUTH DEVELOPMENT - Amount: 20000.0$", "158851 - FY '08 CDBG YOUTH DEVELOPMENT - Amount: 30000.0$", "161058 - FY '10 CORP YOUTH DEVELOPMENT - Amount: 20000.0$", "161848 - YOUTH DEVELOPMENT SERVICES - Amount: 15000.0$", "161931 - FY 03 CDBG-YOUTH SERVICES - Amount: 15000.0$"], "totalAmount": "157235.59999999998$"}]}]}, {"node": "4:5bc9e9e3-9f8e-4060-84df-00fa505e2753:349922", "results": [{"mapping": "IS_RELATED_TO", "query": "\n                MATCH (pr:PersonRecord)-[:RECORD_RESOLVED_TO]->(p:Person)\n                -[:WORKS_FOR_ORG]->(:Organization)\n                -[:BELONGS_TO_ORG_GROUP]->(:OrganizationGroup)<-[:BELONGS_TO_ORG_GROUP]-\n                (o:Organization)<-[:HAS_VENDOR]-(c:ContractRecord)-[:INCLUDED_IN_CONTRACT]->(x:Contract)\n\n                WHERE elementId(p) = $node_id\n                AND c.amount <> 0\n                WITH \n                p.name AS personName,\n                collect(DISTINCT pr.fullName) AS fullNames,\n                collect(DISTINCT o.name) AS orgNames,\n                collect(DISTINCT \n                    c.id + \" - \" + c.name + \" - Amount: \" + toString(c.amount) + \"$\"\n                ) AS contractRecordDetails,\n                toString(sum(DISTINCT c.amount)) + \"$\" AS totalAmount\n\n                RETURN \n                personName,\n                fullNames,\n                orgNames,\n                contractRecordDetails,\n                totalAmount\n                LIMIT 10\n            ", "data": [ ...
#
# === Agent Step ===
# ---FINAL VERSION
# SHACL NodeShape generated and validation run. The detected RDF nodes (subjects) with issues are Persons:
#
# 1. Sister Marie Valerie Chaillou
# 2. Julius Mckinney
# 3. Marie F Rovsselot
# 4. Mother Marie Martha Guibert
# 5. Sister Marie Myriam Guibert
#
# Details for each Person and their related ContractRecords:
#
# 1. Sister Marie Valerie Chaillou
#    - Organization: FRATERNITE NOTRE DAME, INC
#    - ContractRecords and amounts:
#      - 194 - 2014 DELEGATE AWARD - Amount: 15000.0$
#      - 2752 - ORIGINAL - Amount: -1734.5$
#      - 2753 - ORIGINAL - Amount: -5366.1$
#      - 7844 - ORIGINAL - Amount: 4000.0$
#      - 7907 - ORIGINAL - Amount: -500.0$
#      - 7910 - ORIGINAL - Amount: -3500.0$
#      - 11382 - CDBG YOUTH DEVELOPMENT SERVICES - Amount: 25000.0$
#      - 14005 - FY 00 CSBG YOUTH DEVELOPMENT SERVICES - Amount: 40000.0$
#      - 38823 - ORIGINAL - Amount: -6873.1$
#      - 41573 - ORIGINAL - Amount: -1835.4$
#      - 43997 - ORIGINAL - Amount: -6955.3$
#      - 115094 - FY '10 CDBG EMERGENCY FOOD - Amount: 25000.0$
#      - 116306 - EMERGENCY FOOD/FEEDING PROGRAM - Amount: 25000.0$
#      - 119265 - FY 04 CDBG YOUTH DEVELOPMENT - Amount: 20000.0$
#      - 122818 - FY '09 CORP- YOUTH DEVELOPMENT - Amount: 20000.0$
#      - 122836 - FY '07 CDBG YOUTH DEVELOPMENT - Amount: 30000.0$
#      - 124768 - CORP - HUMAN SERVICES DELIVERY - Amount: 15000.0$
#      - 125520 - FY '2009 EMERGENCY FOOD - Amount: 25000.0$
#      - 127568 - 2011 EMERGENCY FOOD PROGRAM - CORPORATE - Amount: 25000.0$
#      - 133716 - FY '2008 EMERGENCY FOOD - Amount: 50000.0$
#      - 139284 - FY '06 - CDBG YOUTH DEVELOPMENT - Amount: 30000.0$
#      - 142365 - FY 05 CDBG-YOUTH SERVICES - Amount: 20000.0$
#      - 144494 - FY '11 CDBG YOUTH DEVELOPMENT - Amount: 20000.0$
#      - 158851 - FY '08 CDBG YOUTH DEVELOPMENT - Amount: 30000.0$
#      - 161058 - FY '10 CORP YOUTH DEVELOPMENT - Amount: 20000.0$
#      - 161848 - YOUTH DEVELOPMENT SERVICES - Amount: 15000.0$
#      - 161931 - FY 03 CDBG-YOUTH SERVICES - Amount: 15000.0$
#    - Total amount: 157235.60$
#
# 2. Julius Mckinney
#    - Organization: CHICAGO FAMILY HEALTH CENTER, INC.
#    - ContractRecords and amounts: (many, including large positive and negative amounts)
#    - Total amount: 8910429.60$
#
# 3. Marie F Rovsselot
#    - Organization: FRATERNITE NOTRE DAME, INC
#    - ContractRecords and amounts: Same as Sister Marie Valerie Chaillou (likely related or same contracts)
#    - Total amount: 157235.60$
#
# 4. Mother Marie Martha Guibert
#    - Organization: FRATERNITE NOTRE DAME, INC
#    - ContractRecords and amounts: Same as Sister Marie Valerie Chaillou (likely related or same contracts)
#    - Total amount: 157235.60$
#
# 5. Sister Marie Myriam Guibert
#    - Organization: FRATERNITE NOTRE DAME, INC
#    - ContractRecords and amounts: Same as Sister Marie Valerie Chaillou (likely related or same contracts)
#    - Total amount: 157235.60$
#
# Summary:
# - Persons are mapped to their related ContractRecords via organizational relationships.
# - ContractRecord amounts vary widely, with Julius Mckinney associated with the largest total amount.
# - The total amounts for the other persons are identical, indicating shared or related contracts within the same organization FRATERNITE NOTRE DAME, INC.
